# %%
import requests
res = requests.get('http://www.appledaily.com.tw/realtimenews/section/new/1')
print res
# Out:
# <Response [200]>

# %%
print res.text
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7 ]> <html lang="zh-TW" class="ie6 ielt8"> <![endif]-->
# <!--[if IE 7 ]>    <html lang="zh-TW" class="ie7 ielt8"> <![endif]-->
# <!--[if IE 8 ]>    <html lang="zh-TW" class="ie8"> <![endif]-->
# <!--[if (gte IE 9)|!(IE)]><!--> <html lang="zh-TW"> <!--<![endif]-->
# <head>
#   <meta charset="utf-8" />
#   <title>蘋果即時新聞｜蘋果日報｜Apple Daily</title>
#   <meta name="description" content="蘋果日報網站提供即時、快速、豐富的最新時事動態，包含國際、社會、娛樂、政治、生活、財經等最新訊息，並為您搜奇地球村萬象與趣聞，強調有圖有真相、影片最明白，讓您時時刻刻掌握天下事！" />
#   <meta name="keywords" content="蘋果日報,Apple Daily,台灣,壹傳媒,Apple, Animation news, Action News, Apple news, news,蘋果,即時,最新,蘋果新聞,新聞,壹週刊,壹電視,動新聞,即時新聞,Facebook,臉書,蘋果粉絲團,plurk,twitter,留言,分享,按讚,天氣,影音新聞,影片,影音,行動版,手機,App,Android,iphone,Mango,爆料,投稿,發票,統一發票,RSS,生活,國際,娛樂,體育,副刊,財經,股市,樂透,威力彩,社會,熱門,彩券,頭彩" />
#   <meta property="og:title" content="蘋果即時新聞｜蘋果日報｜Apple Daily"/>
#   <meta property="og:image" content="http://twimg.edgesuite.net/appledaily/images/core/logo_bg.png"/>
# ...

# %%
from bs4 import BeautifulSoup as bs
soup = bs(res.text)
print soup
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7 ]> <html lang="zh-TW" class="ie6 ielt8"> <![endif]--><!--[if IE 7 ]>    <html lang="zh-TW" class="ie7 ielt8"> <![endif]--><!--[if IE 8 ]>    <html lang="zh-TW" class="ie8"> <![endif]--><!--[if (gte IE 9)|!(IE)]><!--><html lang="zh-TW"> <!--<![endif]-->
# <head>
# <meta charset="utf-8"/>
# <title>蘋果即時新聞｜蘋果日報｜Apple Daily</title>
# <meta content="蘋果日報網站提供即時、快速、豐富的最新時事動態，包含國際、社會、娛樂、政治、生活、財經等最新訊息，並為您搜奇地球村萬象與趣聞，強調有圖有真相、影片最明白，讓您時時刻刻掌握天下事！" name="description"/>
# <meta content="蘋果日報,Apple Daily,台灣,壹傳媒,Apple, Animation news, Action News, Apple news, news,蘋果,即時,最新,蘋果新聞,新聞,壹週刊,壹電視,動新聞,即時新聞,Facebook,臉書,蘋果粉絲團,plurk,twitter,留言,分享,按讚,天氣,影音新聞,影片,影音,行動版,手機,App,Android,iphone,Mango,爆料,投稿,發票,統一發票,RSS,生活,國際,娛樂,體育,副刊,財經,股市,樂透,威力彩,社會,熱門,彩券,頭彩" name="keywords"/>
# <meta content="蘋果即時新聞｜蘋果日報｜Apple Daily" property="og:title"/>
# <meta content="http://twimg.edgesuite.net/appledaily/images/core/logo_bg.png" property="og:image"/>
# ...

# %%
listres = soup.select('.rtddt a')
print listres[0].text
# Out:
# 00:08
# 論壇
# 江春男：孫國父的另一面(0)

# %%
for listress in listres:
    print listress.select('h2')[0].text, listress.select('h1')[0].text , listress.select('h2')[0].text ,\
    listress.select('time')[0].text, listress.select('h2')[0].text
    print 'http://www.appledaily.com.tw' + listress['href']
# Out:
# 論壇 江春男：孫國父的另一面(0) 論壇 00:08 論壇
# http://www.appledaily.com.tw/realtimenews/article/forum/20160224/801796/江春男：孫國父的另一面
# 搜奇 活生生的飾品  能戴還能養(0) 搜奇 00:08 搜奇
# http://www.appledaily.com.tw/realtimenews/article/strange/20160224/801806/活生生的飾品能戴還能養
# 3C 愛麗絲兔夢遊  也愛玩彈珠台(0) 3C 00:07 3C
# http://www.appledaily.com.tw/realtimenews/article/3c/20160224/801629/愛麗絲兔夢遊也愛玩彈珠台
# 搜奇 【占卜】我就是時尚 不服來辯！(0) 搜奇 00:07 搜奇
# http://www.appledaily.com.tw/realtimenews/article/strange/20160224/801720/【占卜】我就是時尚不服來辯！
# 論壇 從衛福部官員中毒談起(0) 論壇 00:06 論壇
# http://www.appledaily.com.tw/realtimenews/article/forum/20160224/800699/從衛福部官員中毒談起
# 搜奇 這些刺青 關了燈看更美(0) 搜奇 00:06 搜奇
# http://www.appledaily.com.tw/realtimenews/article/strange/20160224/801690/這些刺青關了燈看更美
# 3C 5分鐘充飽iPhone？  新尿袋來陰招(0) 3C 00:06 3C
# http://www.appledaily.com.tw/realtimenews/article/3c/20160224/801804/5分鐘充飽iPhone？新尿袋來陰招
# 動物 想要減肥  找毛小孩監督就對了 (77) 動物 00:05 動物
# http://www.appledaily.com.tw/realtimenews/article/animal/20160224/801743/想要減肥找毛小孩監督就對了
# ...

# %%
import pandas as pd
#製作表單
domain = 'http://www.appledaily.com.tw'
ary = []
for listress in listres:
    ary.append({'title':listress.select('h1')[0].text, 'category':listress.select('h2')[0].text, 'time':listress.select('time')[0].text, 'url':listress['href']})
df = pd.DataFrame(ary)
df.head()
# Out:
#   category   time               title  \
# 0       論壇  00:08      江春男：孫國父的另一面(0)
# 1       搜奇  00:08    活生生的飾品  能戴還能養(0)
# 2       3C  00:07   愛麗絲兔夢遊  也愛玩彈珠台(0)
# 3       搜奇  00:07  【占卜】我就是時尚 不服來辯！(0)
# 4       論壇  00:06       從衛福部官員中毒談起(0)
#
#                                                  url
# 0  /realtimenews/article/forum/20160224/801796/江春...
# 1  /realtimenews/article/strange/20160224/801806/...
# 2  /realtimenews/article/3c/20160224/801629/愛麗絲兔夢...
# 3  /realtimenews/article/strange/20160224/801720/...
# 4  /realtimenews/article/forum/20160224/800699/從衛...
